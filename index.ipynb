# %%
import numpy as np
import pandas as pd

# %%
try:
    df = pd.read_csv('repositories.csv', encoding='iso-8859-1')
except Exception as e:
    print(f"An error occurred while reading the CSV file: {e}")

# %%
df
# Out:
#                                                   Name  \
# 0                                         freeCodeCamp
# 1                               free-programming-books
# 2                                              awesome
# 3                                              996.ICU
# 4                          coding-interview-university
# ...                                                ...
# 215024                                     puppet-virt
# 215025                               BounceProgressBar
# 215026  egghead-angularjs-from-scratch-getting-started
# 215027                                           Pcode
# 215028                                     react-hooks
#
#                                               Description  \
# 0       freeCodeCamp.org's open-source codebase and cu...
# 1              :books: Freely available programming books
# 2       ð Awesome lists about all kinds of interest...
# 3       Repo for counting stars and contributing. Pres...
# 4       A complete computer science study plan to beco...
# ...                                                   ...
# 215024        Puppet Module for Virtualization Management
# 215025                   Android BounceProgressBar Widget
# 215026                                                NaN
# 215027                                       Python 3 IDE
# 215028          Fire off actions in stateless components.
#
#                                                       URL  \
# 0            https://github.com/freeCodeCamp/freeCodeCamp
# 1       https://github.com/EbookFoundation/free-progra...
# 2                 https://github.com/sindresorhus/awesome
# 3                       https://github.com/996icu/996.ICU
# 4       https://github.com/jwasham/coding-interview-un...
# ...                                                   ...
# 215024          https://github.com/carlasouza/puppet-virt
# 215025  https://github.com/zhengxiaopeng/BounceProgres...
# 215026  https://github.com/eggheadio/egghead-angularjs...
# 215027                https://github.com/fortharris/Pcode
# 215028                  https://github.com/tj/react-hooks
#
#                   Created At            Updated At  \
# 0       2014-12-24T17:49:19Z  2023-09-21T11:32:33Z
# 1       2013-10-11T06:50:37Z  2023-09-21T11:09:25Z
# 2       2014-07-11T13:42:37Z  2023-09-21T11:18:22Z
# 3       2019-03-26T07:31:14Z  2023-09-21T08:09:01Z
# 4       2016-06-06T02:34:12Z  2023-09-21T10:54:48Z
# ...                      ...                   ...
# 215024  2010-06-06T21:42:34Z  2023-01-27T12:13:50Z
# 215025  2014-11-17T12:19:13Z  2022-11-29T16:50:03Z
# 215026  2014-08-04T12:56:15Z  2022-03-13T19:20:21Z
# 215027  2013-07-29T08:55:29Z  2022-12-15T13:11:25Z
# 215028  2016-09-19T23:26:58Z  2023-09-01T07:10:16Z
#
#                                                  Homepage    Size   Stars  \
# 0                     http://contribute.freecodecamp.org/  387451  374074
# 1       https://ebookfoundation.github.io/free-program...   17087  298393
# 2                                                     NaN    1441  269997
# 3                                         https://996.icu  187799  267901
# 4                                                     NaN   20998  265161
# ...                                                   ...     ...     ...
# 215024                              http://puppetlabs.com     573     167
# 215025                                                NaN    2219     167
# 215026                                                NaN      81     167
# 215027                                                NaN   15617     167
# 215028                                                NaN       3     167
#
#         Forks  Issues  ...  Has Issues Has Projects Has Downloads Has Wiki  \
# 0       33599     248  ...        True         True          True    False
# 1       57194      46  ...        True        False          True    False
# 2       26485      61  ...        True        False          True    False
# 3       21497   16712  ...       False        False          True    False
# 4       69434      56  ...        True        False          True    False
# ...       ...     ...  ...         ...          ...           ...      ...
# 215024     73      11  ...        True         True         False     True
# 215025     36       2  ...        True         True          True     True
# 215026    221       2  ...        True         True          True     True
# 215027     24       4  ...        True         True          True     True
# 215028      9       3  ...        True         True          True     True
#
#         Has Pages  Has Discussions  Is Fork  Is Archived  Is Template  \
# 0            True            False    False        False        False
# 1            True            False    False        False        False
# 2            True            False    False        False        False
# 3           False            False    False         True        False
# 4           False            False    False        False        False
# ...           ...              ...      ...          ...          ...
# 215024      False            False    False        False        False
# 215025      False            False    False        False        False
# 215026      False            False    False        False        False
# 215027      False            False    False        False        False
# 215028      False            False    False        False        False
#
#         Default Branch
# 0                 main
# 1                 main
# 2                 main
# 3               master
# 4                 main
# ...                ...
# 215024          master
# 215025          master
# 215026          master
# 215027          master
# 215028          master
#
# [215029 rows x 24 columns]
